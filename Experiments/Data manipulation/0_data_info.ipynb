# %%
# imports
import sys
import numpy as np
import pandas as pd
sys.path.append('../../') # to access the files in higher directories
sys.path.append('../') # to access the files in higher directories
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import core_exp as cx
import core_calib as cal
import core_tools as ct

# %%
data_list = [
                  "cm1",
                  "datatrieve",
                  "kc1_class_level_defectiveornot",
                  "kc1",
                  "kc2",
                  "kc3",
                  "pc1",
                  "spect",
                  "spectf",
                  "vertebral", 
                  "wilt",
                  "parkinsons", 
                  "heart",
                  "wdbc",
                  "bank", 
                  "ionosphere", 
                  "HRCompetencyScores",
                  "spambase", 
                  "QSAR", 
                  "diabetes", 
                  "breast", 
                  "SPF",
                  "hillvalley",
                  "pc4",
                  "scene",
                  "Sonar_Mine_Rock_Data",
                  "Customer_Churn",
                  "jm1",
                  "eeg",
                  "phoneme",
            ]

# %%
data_info = ct.real_data_info(data_list)
data_info_sorted = data_info.sort_values(by='instances').reset_index()
data_info_sorted.drop(columns=["index"], inplace=True)
data_info_sorted.index = data_info_sorted.index + 1
data_info_sorted["major class"] = data_info_sorted["major class"].round(1)
data_info_sorted.to_latex(f"data_info.txt")
data_info_sorted
# Out:
# /var/folders/gm/nlbfzh25075c0jwn9khghrfw0000gn/T/ipykernel_28532/1034276766.py:6: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   data_info_sorted.to_latex(f"data_info.txt")
#                               Name  instances  features  major class
# 1                       datatrieve        130         8         91.5
# 2   kc1_class_level_defectiveornot        145        94         58.6
# 3                       parkinsons        195        22         75.4
# 4             Sonar_Mine_Rock_Data        208        60         53.4
# 5                            spect        267        22         79.4
# 6                           spectf        267        44         79.4
# ...
